# %% [markdown]
# # Feature Engineering for the Merged Dataset

# %% [markdown]
# ## 1. load required libraries and CSV File

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler 
import pandas as pd
import numpy as np
df = pd.read_csv("Merged_Cleaned_Dataset.csv")

# %% [markdown]
# ## 2. Price per square meter (avoid division by zero)

# %%
df['price_per_sqm'] = df['price'] / df['size']
df['price_per_sqm'] = df['price_per_sqm'].replace([np.inf, -np.inf], np.nan)

# %% [markdown]
# ## 3. Drop rows with missing values in those columns before scaling

# %%
numeric_features = ['price', 'size', 'bedrooms', 'bathrooms', 'price_per_sqm']
df_scaled = df.dropna(subset=numeric_features).copy()

# %% [markdown]
# ## 4. Apply MinMaxScaler

# %%
minmax_scaler = MinMaxScaler()
minmax_scaled = pd.DataFrame(
    minmax_scaler.fit_transform(df_scaled[numeric_features]),
    columns=[col + '_minmax' for col in numeric_features],
    index=df_scaled.index
)

# %% [markdown]
# ## 5. Apply StandardScaler

# %%
standard_scaler = StandardScaler()
standard_scaled = pd.DataFrame(
    standard_scaler.fit_transform(df_scaled[numeric_features]),
    columns=[col + '_std' for col in numeric_features],
    index=df_scaled.index
)

# %% [markdown]
# ## 6. Combine scaled data with original

# %%
df_scaled = pd.concat([df_scaled, minmax_scaled, standard_scaled], axis=1)

# %% [markdown]
# ## 7. Final Preview of the output

# %%
df_scaled.head()
# Out:
#                       property_name             location  bedrooms  bathrooms  \
# 0               2-BEDROOM APARTMENT             Al Ansab         2        2.0
# 1               2-BEDROOM APARTMENT      Shatti Al Qurum         2        2.0
# 2            4+1 BEDROOM TWIN VILLA  Madinat Qaboos (MQ)         5        5.0
# 4           COMMERCIAL OFFICE SPACE              Bausher         2        2.0
# 5  2, 3 & 4-BEDROOM COMPOUND VILLAS               Rusayl         3        3.0
#
#     price   size  price_per_sqm  price_minmax  size_minmax  bedrooms_minmax  \
# 0   300.0  120.0       2.500000      0.002041      0.00011         0.166667
# 1   500.0  120.0       4.166667      0.003421      0.00011         0.166667
# 2  1500.0  120.0      12.500000      0.010318      0.00011         0.416667
# 4     4.0  120.0       0.033333      0.000000      0.00011         0.166667
# 5   650.0  120.0       5.416667      0.004455      0.00011         0.250000
#
#    bathrooms_minmax  price_per_sqm_minmax  price_std  size_std  bedrooms_std  \
# 0          0.166667              0.002069  -0.055697 -0.070984     -0.398518
# 1          0.166667              0.003448   0.023518 -0.070984     -0.398518
# 2          0.416667              0.010345   0.419594 -0.070984      1.115989
# 4          0.166667              0.000028  -0.172936 -0.070984     -0.398518
# 5          0.250000              0.004483   0.082929 -0.070984      0.106318
#
#    bathrooms_std  price_per_sqm_std
# 0      -0.398518          -0.065876
# 1      -0.398518           0.004288
# 2       1.115989           0.355111
# 4      -0.398518          -0.169720
# 5       0.106318           0.056912

# %%
df.head()
# Out:
#              property_name             location  bedrooms  bathrooms   price  \
# 0      2-BEDROOM APARTMENT             Al Ansab         2        2.0   300.0
# 1      2-BEDROOM APARTMENT      Shatti Al Qurum         2        2.0   500.0
# 2   4+1 BEDROOM TWIN VILLA  Madinat Qaboos (MQ)         5        5.0  1500.0
# 3          COMMERCIAL SHOP                Ghala         2        NaN   370.0
# 4  COMMERCIAL OFFICE SPACE              Bausher         2        2.0     4.0
#
#     size  price_per_sqm
# 0  120.0       2.500000
# 1  120.0       4.166667
# 2  120.0      12.500000
# 3   39.0       9.487179
# 4  120.0       0.033333

# %%
df.tail()
# Out:
#                                           property_name             location  \
# 4489                                  Room for bachelor      Azaiba, Muscat•
# 4490                                       Sharing room  Al Ghubrah, Muscat•
# 4491                                   شقق وغرف للايجار  Al Khuwair, Muscat•
# 4492  شقة للايجار الدور الثاني العامرات… (للتواصل وا...   Al Amarat, Muscat•
# 4493                                        صلالة صحنوت     Salalah, Dhofar•
#
#       bedrooms  bathrooms  price   size  price_per_sqm
# 4489         1        1.0  100.0   10.0      10.000000
# 4490         2        2.0   60.0   20.0       3.000000
# 4491         1        1.0  200.0   50.0       4.000000
# 4492         3        3.0  130.0  131.0       0.992366
# 4493         5        5.0  140.0  300.0       0.466667

# %%
df.to_csv("Final_Dataset.csv", index=False)
